# %% [markdown]
# ## Objective
#
# This notebook covers the following tasks:
# - Pedagogical Recommendations
# - Dashboard development
# - Dashboard validation

# %%
import pandas as pd

# Pedagogical Recommendations
# Edit the recommendations below to customize per profile if needed
# Full mapping rationale documented in docs/references.md
# The recommendations are in Portuguese to match the use case

recommendations = {
    "Analytical": [
        ("Oferecer desafios matemáticos e lógicos além do currículo padrão - puzzles, problemas de raciocínio e projetos de investigação independente", "Gardner (1983) - Inteligência Lógico-Matemática"),
        ("Estimular atividades de pesquisa estruturada com etapas definidas, incentivando o pensamento científico e a resolução sistemática de problemas", "Gardner (1983) - Inteligência Espacial"),
        ("Promover atividades colaborativas para desenvolver habilidades interpessoais, equilibrando os pontos fortes analíticos com competências sociais", "Antunes (1998)"),
    ],
    "Communicative": [
        ("Utilizar narrativas, debates e discussões em grupo como principais veículos de aprendizado", "Gardner (1983) - Inteligência Linguística e Interpessoal"),
        ("Atribuir papéis de liderança em atividades em grupo - mediador, porta-voz, organizador", "Gardner (1983) - Inteligência Interpessoal"),
        ("Incentivar expressão escrita e oral por meio de diários, apresentações e peer teaching", "Armstrong (2001)"),
    ],
    "Kinesthetic": [
        ("Incorporar atividades práticas, construção de modelos e movimento físico nas aulas", "Gardner (1983) - Inteligência Corporal-Cinestésica"),
        ("Estruturar a rotina em blocos curtos e variados de tarefas para apoiar a regulação emocional", "CASEL (2020) - Autogestão"),
        ("Reconhecer que comportamentos de agitação podem refletir necessidade de estímulo cinestésico, não indisciplina", "Brasil. MEC/SEESP (2008)"),
    ],
    "Balanced": [
        ("Manter estratégias de ensino variadas para sustentar o engajamento em múltiplas dimensões", "Gardner (1983) - Teoria das Inteligências Múltiplas"),
        ("Oferecer atividades de enriquecimento em diferentes áreas para identificar potenciais latentes", "Brasil. MEC/SEESP (2006) - Altas Habilidades"),
        ("Monitorar indicadores socioemocionais ao longo do tempo para detectar padrões emergentes", "Fredricks, Blumenfeld & Paris (2004)"),
    ],
}

rec_rows = []
for profile, recs in recommendations.items():
    for i, (rec, source) in enumerate(recs, 1):
        rec_rows.append({"profile": profile, "order": i, "recommendation": rec, "source": source})

rec_df = pd.DataFrame(rec_rows)
rec_df.to_csv("../data/recommendations.csv", index=False)

print("Recommendations saved to data/recommendations.csv")
rec_df
# Out:
# Recommendations saved to data/recommendations.csv
#           profile  order                                     recommendation  \
# 0      Analytical      1  Oferecer desafios matemáticos e lógicos além d...
# 1      Analytical      2  Estimular atividades de pesquisa estruturada c...
# 2      Analytical      3  Promover atividades colaborativas para desenvo...
# 3   Communicative      1  Utilizar narrativas, debates e discussões em g...
# 4   Communicative      2  Atribuir papéis de liderança em atividades em ...
# 5   Communicative      3  Incentivar expressão escrita e oral por meio d...
# 6     Kinesthetic      1  Incorporar atividades práticas, construção de ...
# 7     Kinesthetic      2  Estruturar a rotina em blocos curtos e variado...
# 8     Kinesthetic      3  Reconhecer que comportamentos de agitação pode...
# 9        Balanced      1  Manter estratégias de ensino variadas para sus...
# 10       Balanced      2  Oferecer atividades de enriquecimento em difer...
# ...
